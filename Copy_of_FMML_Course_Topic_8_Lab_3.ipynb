# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumathiii24/FMML_COURSE_ASSIGNMENT/blob/main/Copy_of_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-06 16:20:12--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  85.5MB/s    in 0.8s
#
# 2024-04-06 16:20:14 (85.5 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7806   1803.04926v2  Active Reinforcement Learning (ARL) is a twist...    cs
# 33616   1410.1151v1  In this article, we propose a combination of a...    cs
# 11092   1404.7796v2  In the past few years, a lot of attention has ...  stat
# 16639  1704.07130v1  We study a symmetric collaborative dialogue se...    cs
# 35774   1204.4307v1  Based on Cumulative Number of Confirmed Human ...    cs
# ...             ...                                                ...   ...
# 11688  1609.09196v1  Thanks to the rise of wearable and connected d...  stat
# 7535   1802.01284v1  In recent years, neural network approaches hav...    cs
# 40974   1312.4108v1  Although Support Vector Machine (SVM) algorith...    cs
# 31319  1803.00004v1  Computational complexity of the brute-force im...    cs
# 6314   1611.02258v2  In this paper, we consider a new low-quality l...  stat
#
#                                                    title  year  \
# 7806   Active Reinforcement Learning with Monte-Carlo...  2018
# 33616  Training Algorithm for Neuro-Fuzzy Network Bas...  2014
# 11092  Majority Vote of Diverse Classifiers for Late ...  2014
# 16639  Learning Symmetric Collaborative Dialogue Agen...  2017
# 35774  Avian Influenza (H5N1) Warning System using De...  2012
# ...                                                  ...   ...
# 11688  EXTRACT: Strong Examples from Weakly-Labeled S...  2016
# 7535   Task-Aware Compressed Sensing with Generative ...  2018
# 40974  A MapReduce based distributed SVM algorithm fo...  2013
# 31319  Speeding Up the Bilateral Filter: A Joint Acce...  2018
# 6314   Learning Time Series Detection Models from Tem...  2016
#
#                                                 keywords
# 7806   [reinforcement, information, exploration, subs...
# 33616  [combination, reduction, algorithm, feedforwar...
# 11092  [attention, multimedia, multimodal, informatio...
# 16639  [symmetric, collaborative, knowledge, strategi...
# 35774  [cumulative, confirmed, influenza, organizatio...
# ...                                                  ...
# 11688  [connected, generated, unfortunately, extracti...
# 7535   [approaches, applications, unsupervised, gener...
# 40974  [algorithm, generalization, algorithm, classif...
# 31319  [computational, complexity, implementation, bi...
# 6314   [detection, temporally, imprecise, supervision...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7806     [reinforcement, information, exploration, subs...
# 33616    [combination, reduction, algorithm, feedforwar...
# 11092    [attention, multimedia, multimodal, informatio...
# 16639    [symmetric, collaborative, knowledge, strategi...
# 35774    [cumulative, confirmed, influenza, organizatio...
#                                ...
# 26472    [attractive, occlusion, deformation, represent...
# 10537    [ancestral, introduced, richardson, generalize...
# 2425     [algorithms, experience, efficiently, processe...
# 31768    [describes, methodology, detecting, anomalies,...
# 33383    [optimization, classifier, presented, personne...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8712 words.
# Out of those 4509 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="38b5497b-4e58-41cc-ad7e-7062705d9bf7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38b5497b-4e58-41cc-ad7e-7062705d9bf7")) {                    Plotly.newPlot(                        "38b5497b-4e58-41cc-ad7e-7062705d9bf7",                        [{"x":["behaviour","analysing","outperforms","algorithm","principles","exploration","augmented","obstacles","algorithms","environments","experimentally","heuristics","challenging","information","asymptotically","specialised","substantially","reinforcement","simulation","processed","procedure","international","combination","performances","different","backpropagation","preprocessing","filtering","reduction","basically","prediction","increases","successfully","feedforward","multilayer","technique","comparison","predictability","precision","classifiers","quadratic","diversity","naturally","multimedia","benchmark","considered","extension","investigate","attention","preserving","functions","generally","classifier","misclassification","multimodal","procedures","maximizing","informations","dialogues","collaborative","strategic","automatic","communicate","knowledge","unstructured","collected","structured","achieving","symmetric","evaluations","interesting","progresses","embeddings","effective","challenges","strategically","conditions","ignorance","displaying","visualize","quantitative","identified","organization","disorders","visualization","institutions","hypotheses","countries","researcher","identification","existence","influenza","displayed","population","narrowness","confirmed","provision","uncertainty","measurement","plausibility","individuals","cumulative","geographically","depression","extracting","solutions","background","variation","alternative","multipliers","associated","iterative","introducing","experimental","direction","regression","regularization","developed","efficient","simultaneously","enforcing","decomposes","presented","approaches","complicate","framework","contiguous","deviation","selection","optimization","architectures","operators","surprisingly","magnitude","cumbersome","competitive","resources","architecture","convolutional","typically","morphisms","requiring","performing","automatically","annealing","competing","construct","continuous","irregular","reproducing","exploiting","implicitly","artificial","nonlinear","classical","formulation","resulting","recursive","considering","extracted","outperform","structure","explicitly","important","computational","separately","adaptively","combinations","confidence","parameter","generalized","dimensional","including","demonstrate","likelihood","approximation","estimating","independent","concentration","illustrate","consequences","unbounded","parameters","directional","incomplete","statistical","inequalities","nonconvex","addresses","particular","inferential","statistics","misspecified","heterogeneous","components","regularized","multitask","estimators","contributions","extensive"],"y":[40,13,256,813,24,44,37,13,607,88,43,43,260,665,14,3,41,104,82,25,117,14,145,44,758,18,30,60,104,5,202,58,86,19,16,231,146,6,67,116,38,53,51,12,190,124,80,133,185,52,206,73,146,12,24,36,32,1,8,33,7,201,8,321,22,77,99,86,21,55,82,6,66,250,122,4,126,3,3,10,64,42,18,6,28,7,19,9,4,105,27,2,15,57,2,9,2,83,24,7,35,11,2,1,57,163,76,53,99,12,95,71,40,395,61,108,84,191,388,116,14,12,186,428,2,548,1,15,152,339,114,41,22,41,6,120,96,238,339,102,1,34,110,166,17,27,91,111,11,14,68,25,133,66,110,84,143,23,71,122,85,356,57,354,312,28,31,33,53,133,58,187,246,561,65,116,64,121,13,77,10,8,253,19,31,165,8,10,50,260,3,46,1,32,79,43,6,18,46,158],"type":"bar"},{"x":["behaviour","analysing","outperforms","algorithm","principles","exploration","augmented","obstacl ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4509,), (4509, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>EndoVO</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.44186046511627913);'>Recurrent</span> <span style='background-color:rgba(0, 255, 0, 0.5586206896551724);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>(RCNN)</span> <span style=''>based</span> <span style=''>Visual</span> <span style=''>Odometry</span> <span style=''>Approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Endoscopic</span> <span style=''>Capsule</span> <span style=''>Robots</span> <br/><br/><span style=''>Ingestible</span> <span style=''>wireless</span> <span style=''>capsule</span> <span style=''>endoscopy</span> <span style=''>is</span> <span style=''>an</span> <span style=''>emerging</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>minimally</span> <span style=''>invasive</span> <span style='background-color:rgba(0, 255, 0, 0.4482758620689655);'>diagnostic</span> <span style='background-color:rgba(0, 255, 0, 0.71875);'>technology</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.8571428571428572);'>inspection</span> <span style=''>of</span> <span style=''>the</span> <span style=''>GI</span> <span style=''>tract</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4181818181818182);'>diagnosis</span> <span style=''>of</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style=''>diseases</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>pathologies</span> <span style=''>Medical</span> <span style=''>device</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>companies</span> <span style=''>and</span> <span style=''>many</span> <span style=''>research</span> <span style=''>groups</span> <span style=''>have</span> <span style=''>recently</span> <span style=''>made</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>substantial</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>progresses</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.42857142857142855);'>converting</span> <span style=''>passive</span> <span style=''>capsule</span> <span style=''>endoscopes</span> <span style=''>to</span> <span style=''>active</span> <span style=''>capsule</span> <span style=''>robots</span> <span style=''>enabling</span> <span style=''>more</span> <span style=''>accurate</span> <span style=''>precise</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuitive</span> <span style='background-color:rgba(0, 255, 0, 0.5402843601895735);'>detection</span> <span style=''>of</span> <span style=''>the</span> <span style=''>location</span> <span style=''>and</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style=''>diseased</span> <span style=''>areas</span> <span style=''>Since</span> <span style=''>a</span> <span style=''>reliable</span> <span style=''>real</span> <span style=''>time</span> <span style=''>pose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>functionality</span> <span style=''>is</span> <span style=''>crucial</span> <span style=''>for</span> <span style=''>actively</span> <span style='background-color:rgba(0, 255, 0, 0.48148148148148157);'>controlled</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>endoscopic</span> <span style=''>capsule</span> <span style=''>robots</span> <span style=''>in</span> <span style=''>this</span> <span style=''>study</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>monocular</span> <span style=''>visual</span> <span style=''>odometry</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>PAC</span> <span style=''>Bayesian</span> <span style=''>Learning</span> <span style=''>and</span> <span style=''>Domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adaptation</span> <br/><br/><span style=''>In</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>Domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adaptation</span> <span style=''>(DA)</span> <span style=''>arises</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>gen</span> <span style=''>erating</span> <span style=''>the</span> <span style=''>test</span> <span style=''>(target)</span> <span style=''>data</span> <span style=''>differs</span> <span style=''>from</span> <span style=''>the</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generating</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>(source)</span> <span style=''>data</span> <span style=''>It</span> <span style=''>is</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>DA</span> <span style=''>is</span> <span style=''>an</span> <span style=''>hard</span> <span style=''>task</span> <span style=''>even</span> <span style=''>under</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>among</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariate</span> <span style=''>shift</span> <span style=''>where</span> <span style=''>the</span> <span style=''>source</span> <span style=''>and</span> <span style=''>target</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>diverge</span> <span style=''>only</span> <span style=''>in</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>marginals</span> <span style=''>ie</span> <span style=''>they</span> <span style=''>have</span> <span style=''>the</span> <span style=''>same</span> <span style=''>labeling</span> <span style=''>function</span> <span style=''>Another</span> <span style=''>popular</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>to</span> <span style=''>consider</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>class</span> <span style=''>that</span> <span style=''>moves</span> <span style=''>closer</span> <span style=''>the</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>while</span> <span style=''>implying</span> <span style=''>a</span> <span style=''>low</span> <span style=''>error</span> <span style=''>for</span> <span style=''>both</span> <span style=''>tasks</span> <span style=''>This</span> <span style=''>is</span> <span style=''>a</span> <span style=''>VC</span> <span style=''>dim</span> <span style=''>approach</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricts</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>class</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>get</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>Instead</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>PAC</span> <span style=''>Bayesian</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>seeks</span> <span style=''>for</span> <span style=''>suitable</span> <span style=''>weights< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Austerity</span> <span style=''>in</span> <span style=''>MCMC</span> <span style=''>Land</span> <span style=''>Cutting</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.39999999999999997);'>Metropolis</span> <span style=''>Hastings</span> <span style=''>Budget</span> <br/><br/><span style=''>Can</span> <span style=''>we</span> <span style=''>make</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.6116504854368932);'>posterior</span> <span style=''>MCMC</span> <span style=''>sampling</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>when</span> <span style=''>faced</span> <span style=''>with</span> <span style=''>very</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>We</span> <span style=''>argue</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4672131147540983);'>likelihood</span> <span style=''>for</span> <span style=''>N</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>datapoints</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.39999999999999997);'>Metropolis</span> <span style=''>Hastings</span> <span style=''>(MH)</span> <span style=''>test</span> <span style=''>to</span> <span style=''>reach</span> <span style=''>a</span> <span style=''>single</span> <span style=''>binary</span> <span style=''>decision</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inefficient</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>MH</span> <span style=''>rule</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>test</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>accept</span> <span style=''>or</span> <span style=''>reject</span> <span style=''>samples</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>confidence</span> <span style=''>using</span> <span style=''>only</span> <span style=''>a</span> <span style=''>fraction</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>required</span> <span style=''>for</span> <span style=''>the</span> <span style=''>exact</span> <span style=''>MH</span> <span style=''>rule</span> <span style=''>While</span> <span style=''>this</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduces</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.6923076923076923);'>asymptotic</span> <span style=''>bias</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style=''>bias</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.48148148148148157);'>controlled</span> <span style=''>and</span> <span style=''>is</span> <span style=''>more</span> <span style=''>than</span> <span style=''>offset</span> <span style=''>by</span> <span style=''>a</span> <span style=''>decrease</span> <span style=''>in</span> <span style=''>variance</span> <span style=''>due</span> <span style=''>to</span> <span style=''>our</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>draw</span> <span style=''>more< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Representation</span> <span style=''>of</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(DNNs)</span> <span style=''>have</span> <span style=''>become</span> <span style=''>very</span> <span style=''>popular</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>in</span> <span style=''>many</span> <span style=''>areas</span> <span style=''>Their</span> <span style=''>strength</span> <span style=''>is</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>with</span> <span style=''>a</span> <span style=''>high</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>that</span> <span style=''>are</span> <span style=''>commonly</span> <span style=''>learned</span> <span style=''>via</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>or</span> <span style=''>similar</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>methods</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>is</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>standardized</span> <span style=''>and</span> <span style=''>the</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculation</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>that</span> <span style=''>break</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>down</span> <span style=''>into</span> <span style=''>scalar</span> <span style=''>units</span> <span style=''>instead</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considering</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>as</span> <span style=''>whole</span> <span style=''>entities</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addressed</span> <span style=''>Standard</span> <span style=''>notation</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>DNNs</span> <span style=''>in</span> <span style=''>a</span> <span style=''>compact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Gradients</span> <span style=''>of</span> <span style=''>DNN</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculated</span> <span style=''>directly</span> <span style=''>over</span> <span style=''>the</span> <span style=''>inner</span> <span style=''>product</span> <span style=''>space</span> <span style=''>on</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>are</span> <span style=''>defined</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07158119658119658)
# 	evaluation (0.10007122507122507)
# 	segmentation (0.0673076923076923)
# 	architecture (0.08475783475783476)
# 	experimental (0.14066951566951566)
# 	information (0.23682336182336183)
# 	detection (0.11574074074074074)
# 	convolutional (0.12072649572649573)
# 	recognition (0.13354700854700854)
# 	different (0.26994301994301995)
#
# Some Statistics words are:
# 	stochastic (0.1330321285140562)
# 	variables (0.13654618473895583)
# 	estimation (0.16415662650602408)
# 	statistical (0.15210843373493976)
# 	theoretical (0.1501004016064257)
# 	algorithm (0.3970883534136546)
# 	dimensional (0.1757028112449799)
# 	distribution (0.1897590361445783)
# 	inference (0.1922690763052209)
# 	regression (0.1852409638554217)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b89b7747-4c0e-4811-9552-14b3426356a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b89b7747-4c0e-4811-9552-14b3426356a2")) {                    Plotly.newPlot(                        "b89b7747-4c0e-4811-9552-14b3426356a2",                        [{"x":["behaviour","analysing","outperforms","algorithm","principles","exploration","augmented","obstacles","algorithms","environments","experimentally","heuristics","challenging","information","asymptotically","specialised","substantially","reinforcement","simulation","processed","procedure","international","combination","performances","different","backpropagation","preprocessing","filtering","reduction","basically","prediction","increases","successfully","feedforward","multilayer","technique","comparison","predictability","precision","classifiers","quadratic","diversity","naturally","multimedia","benchmark","considered","extension","investigate","attention","preserving","functions","generally","classifier","misclassification","multimodal","procedures","maximizing","informations","dialogues","collaborative","strategic","automatic","communicate","knowledge","unstructured","collected","structured","achieving","symmetric","evaluations","interesting","progresses","embeddings","effective","challenges","strategically","conditions","ignorance","displaying","visualize","quantitative","identified","organization","disorders","visualization","institutions","hypotheses","countries","researcher","identification","existence","influenza","displayed","population","narrowness","confirmed","provision","uncertainty","measurement","plausibility","individuals","cumulative","geographically","depression","extracting","solutions","background","variation","alternative","multipliers","associated","iterative","introducing","experimental","direction","regression","regularization","developed","efficient","simultaneously","enforcing","decomposes","presented","approaches","complicate","framework","contiguous","deviation","selection","optimization","architectures","operators","surprisingly","magnitude","cumbersome","competitive","resources","architecture","convolutional","typically","morphisms","requiring","performing","automatically","annealing","competing","construct","continuous","irregular","reproducing","exploiting","implicitly","artificial","nonlinear","classical","formulation","resulting","recursive","considering","extracted","outperform","structure","explicitly","important","computational","separately","adaptively","combinations","confidence","parameter","generalized","dimensional","including","demonstrate","likelihood","approximation","estimating","independent","concentration","illustrate","consequences","unbounded","parameters","directional","incomplete","statistical","inequalities","nonconvex","addresses","particular","inferential","statistics","misspecified","heterogeneous","components","regularized","multitask","estimators","contributions","extensive","semiparametric","asymptotic","probability","properties","supervised","numerical","especially","improvement","specified","discriminative","classification","probabilistic","estimator","unlabeled","experiments","estimation","community","formalized","usefulness","generating","generation","generated","reference","attributes","effectiveness","attribute","calculating","applications","performance","retraining","particles","independently","replicated","practical","demonstrates","inference","particularly","estimates","approximate","cytometry","inconsistent","populations","proposing","available","characterize","synthetic","introduce","generalize","permutation","reweighting","distribution","techniques","distributional","theoretical","distributionally","gen ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	cytometry
# 	variabilities
# 	correspondingly
# 	hypercube
# 	exponentiated
# 	quadrature
# 	amortization
# 	inversions
# 	tensorflow
# 	linearnonlinear
# 	particulars
# 	misspecification
# 	directionally
# 	presenceabsence
# 	inpatient
# 	heteroscedastic
# 	heartbeat
# 	pathology
# 	recasting
# 	lindenstrauss
# Some words which never appear in Statistics papers:
# 	specialised
# 	dialogues
# 	strategically
# 	influenza
# 	narrowness
# 	histology
# 	adventure
# 	programmable
# 	ontologies
# 	interoperability
# 	negotiation
# 	abductive
# 	encodings
# 	abduction
# 	multiplanar
# 	portuguese
# 	segmenter
# 	mistakenly
# 	discussing
# 	telecommunications

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.068520052778545e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7491666666666666
